# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
save_results = True

# %%
with open('results/lambda_4_no_cascade/results_lambda_4_no_cascade.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_4 = np.linspace(*results['crange'])
    results_4 = results['results']

# %%
n_ap_4 = []
for result in results_4:
    n_ap_loc = sum(run['n_ap'] for run in result['runs'])
    n_ap_4.append(n_ap_loc / N / nruns)

# %%
with open('results/lambda_6_no_cascade/results_lambda_6_no_cascade.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_6 = np.linspace(*results['crange'])
    results_6 = results['results']

# %%
n_ap_6 = []
for result in results_6:
    n_ap_loc = sum(run['n_ap'] for run in result['runs'])
    n_ap_6.append(n_ap_loc / N / nruns)

# %%
with open('results/lambda_3/results_lambda_3.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_3 = np.linspace(*results['crange'])
    results_3 = results['results']

# %%
n_ap_3 = []
for result in results_3:
    n_ap_loc = sum(run['cascade'][0]['n_ap'] for run in result['runs'])
    n_ap_3.append(n_ap_loc / N / nruns)

# %%
with open('results/lambda_3.5/results_lambda_3.5.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_3_5 = np.linspace(*results['crange'])
    results_3_5 = results['results']

# %%
n_ap_3_5 = []
for result in results_3_5:
    n_ap_loc = sum(run['cascade'][0]['n_ap'] for run in result['runs'])
    n_ap_3_5.append(n_ap_loc / N / nruns)

# %%
with open('results/lambda_2.5/results_lambda_2.5.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_2_5 = np.linspace(*results['crange'])
    results_2_5 = results['results']

# %%
n_ap_2_5 = []
for result in results_2_5:
    n_ap_loc = sum(run['cascade'][0]['n_ap'] for run in result['runs'])
    n_ap_2_5.append(n_ap_loc / N / nruns)

# %%
with open('results/lambda_3_3.5/results_lambda_3_3.5.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_3_35 = np.linspace(*results['crange'])
    results_3_35 = results['results']

# %%
n_ap_3_35 = []
for result in results_3_35:
    n_ap_loc = sum(run['cascade'][0]['n_ap'] for run in result['runs'])
    n_ap_3_35.append(n_ap_loc / N / nruns)

# %%
with open('results/lambda_3_4/results_lambda_3_4.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_3_4 = np.linspace(*results['crange'])
    results_3_4 = results['results']

# %%
n_ap_3_4 = []
for result in results_3_4:
    n_ap_loc = sum(run['cascade'][0]['n_ap'] for run in result['runs'])
    n_ap_3_4.append(n_ap_loc / N / nruns)

# %%
with open('results/ER/results_ER.json', 'r') as json_file:
    results = json.load(json_file)
    N = results['N']
    nruns = results['nruns']
    crange_ER = np.linspace(*results['crange'])
    results_ER = results['results']

# %%
n_ap_ER = []
for result in results_ER:
    n_ap_loc = sum(run['cascade'][0]['n_ap'] for run in result['runs'])
    n_ap_ER.append(n_ap_loc / N / nruns)

# %%
lw, ms = 1, 4

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=36, **{'family': 'sans-serif', 'sans-serif': ['Helvetica']})
plt.rcParams['xtick.major.pad'] = 8
plt.rcParams['ytick.major.pad'] = 8
plt.rcParams['savefig.bbox'] = 'tight'

# %%
fontsize = 30
labelsize = 30
legendsize = 18
x_crit = 6.08

# %%
plt.plot(crange_2_5, n_ap_2_5, 'o-', lw=lw, ms=ms, color='tab:brown', label='$\lambda = 2.5$')
plt.plot(crange_3, n_ap_3, 's-', lw=lw, ms=ms, color='tab:blue', label='$\lambda = 3$')
plt.plot(crange_3_5, n_ap_3_5, '^-', lw=lw, ms=ms, color='tab:purple', label='$\lambda = 3.5$')
plt.plot(crange_4, n_ap_4, 'x-', lw=lw, ms=ms, color='tab:red', label='$\lambda = 4$')
plt.plot(crange_6, n_ap_6, 'v-', lw=lw, ms=ms, color='tab:green', label='$\lambda = 6$')
# plt.plot(crange_3_35, n_ap_3_35, 'o-', lw=lw, ms=ms, color='tab:pink', label='$\lambda_1 = 3 \lambda_2 = 3.5$')
# plt.plot(crange_3_4, n_ap_3_4, 'o-', lw=lw, ms=ms, color='tab:gray', label='$\lambda_1 = 3 \lambda_2 = 4$')
plt.plot(crange_ER, n_ap_ER, 'P-', lw=lw, ms=ms, color='tab:orange', label='$\mathrm{ER}$')
plt.xlim(0, 8)
plt.ylim(0, .4)
plt.legend(fontsize=legendsize)
plt.xlabel('$c$', fontdict={'size': fontsize})
plt.ylabel('$n_{AP}$', fontdict={'size': fontsize})
plt.xticks([0, 2, 4, 6, 8])
plt.tick_params(axis='both', which='major', labelsize=labelsize)
if save_results:
    plt.savefig(f'results/model_comparison.pdf')
    plt.savefig(f'results/model_comparison.png')
