# %%
import json
from datetime import datetime

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from tqdm import tqdm

import sys
import os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    sys.path.append(os.path.join(module_path, 'network_models'))
from network_models.multiplex_network import create_multiplex_network

# %%
def find_component(node, connected_components):
    for i, component in enumerate(connected_components):
        if node in component:
            return i
    raise ValueError(f'Component for node {node} not found')

# %%
def cascade_remove_links(Ga, Gb):

    keep_going = True
    while keep_going:
        keep_going = False

        clusters_a = list(nx.connected_components(Ga))
        for edge in Gb.edges():
            if find_component(edge[0], clusters_a) != find_component(edge[1], clusters_a):
                keep_going = True
                Gb.remove_edge(*edge)

        clusters_b = list(nx.connected_components(Gb))
        for edge in Ga.edges():
            if find_component(edge[0], clusters_b) != find_component(edge[1], clusters_b):
                keep_going = True
                Ga.remove_edge(*edge)
    
    return Ga, Gb

# %%
def articulation_points_multiplex(G1, G2):
    ap1 = set(nx.articulation_points(G1))
    ap2 = set(nx.articulation_points(G2))
    return ap1.union(ap2)

# %%
def max_comp(G):
    return max(len(comp) for comp in nx.connected_components(G))

# %%
def remove_ap(G1, G2):
    G1, G2 = cascade_remove_links(G1, G2)

    art_points = articulation_points_multiplex(G1, G2)
    gcc_size = max_comp(G1)

    # np.save('n_ap', n_ap)
    # np.save('gcc_size', gcc_size)

    G1.remove_nodes_from(art_points)
    G2.remove_nodes_from(art_points)

    return G1, G2, art_points, gcc_size

# %%
def dt():
    return str(datetime.now()).replace(':', '-')

# %%
crange = np.linspace(0, 12, 100)
N = 1000
gamma = 3
nruns = 1
network_type = 'erdos_renyi'
# network_type = 'scale_free'
save_results = False

# %%
def run(N, crange, gamma, nruns, network_type, save_results):    
    results = []
    for c in tqdm(crange):

        results.append({})
        results[-1]['c'] = c
        results[-1]['runs'] = []

        for run_id in range(nruns):

            results[-1]['runs'].append({})
            current_run = results[-1]['runs'][-1]
            current_run['run_id'] = run_id
            current_run['cascade'] = []

            # G1, G2 = create_multiplex_network({
            #     'type': 'scale_free',
            #     'num_nodes': N,
            #     'mean_degree': c,
            #     'exponent': gamma,
            # })
            G1, G2 = create_multiplex_network({
                'type': 'erdos_renyi',
                'num_nodes': N,
                'mean_degree': c,
            })

            while True:

                current_run['cascade'].append({'t': current_run['cascade'][-1]['t'] + 1
                                                    if current_run['cascade']
                                                    else 0})
                G1, G2, art_points, gcc_size = remove_ap(G1, G2)
                current_run['cascade'][-1]['n_ap'] = len(art_points)
                current_run['cascade'][-1]['gcc_size'] = gcc_size

                if not art_points:
                    break

    if save_results:
        with open(f'results_{dt()}.json', 'w') as json_file:
            json.dump({
                'N': N,
                'nruns': nruns,
                'crange': [crange[0], crange[-1]],
                'results': results,
            }, json_file, indent=4)
    
    return results

# %%
results = run(N, crange, gamma, nruns, network_type, save_results)
# Out:
# 100%|██████████| 100/100 [00:47<00:00,  2.12it/s]

# %%
import pstats

# %%
p = pstats.Stats('run.prof')
p.sort_stats('ncalls').print_stats()
# Out:
# Fri Apr  7 16:01:17 2023    run.prof
#
#          485997859 function calls (478611189 primitive calls) in 249.739 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#  84864950   29.626    0.000   29.626    0.000 C:\Users\kuzne\AppData\Local\Temp\ipykernel_54200\1011066748.py:1(find_component)
#  45384382    5.155    0.000    5.155    0.000 {built-in method builtins.next}
# 43486885/36100215    7.476    0.000    9.126    0.000 {built-in method builtins.iter}
#  42454399   16.064    0.000   16.073    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\reportviews.py:1267(__iter__)
#  30263910    3.014    0.000    3.014    0.000 {method 'add' of 'set' objects}
#  30057033    3.903    0.000    3.903    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\coreviews.py:44(__init__)
#  30055033    5.969    0.000   10.563    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\coreviews.py:50(__iter__)
#  30055033   12.505    0.000   16.407    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\coreviews.py:81(__getitem__)
#  29684784   13.035    0.000   20.900    0.000 {method 'update' of 'set' objects}
#  18985487    3.404    0.000    3.404    0.000 {built-in method builtins.min}
#  13778222    1.443    0.000    1.443    0.000 {built-in method builtins.len}
#  12021394    8.622    0.000    8.622    0.000 {built-in method _bisect.bisect_left}
#  12021394   26.214    0.000   26.214    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#   8001142    1.013    0.000    1.013    0.000 {method 'update' of 'dict' objects}
#   7386672    0.709    0.000    0.709    0.000 {method 'pop' of 'list' objects}
#   7386670    2.707    0.000    7.262    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:493(__getitem__)
#   7042532    5.138    0.000   59.511    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\algorithms\components\connected.py:15(connected_components)
#   7016421   19.427    0.000   53.279    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\algorithms\components\connected.py:188(_plain_bfs)
#   6010697    2.252    0.000    3.017    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:1250(neighbors)
#   6007040    0.687    0.000    0.687    0.000 {method 'get' of 'dict' objects}
#   5999040    7.557    0.000    9.061    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:863(add_edge)
#   5392931    0.605    0.000    0.605    0.000 {method 'append' of 'list' objects}
#   1003700    0.452    0.000   10.336    0.000 C:\Users\kuzne\AppData\Local\Temp\ipykernel_54200\3471748023.py:2(<genexpr>)
#    874847    0.525    0.000    0.525    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:1026(remove_edge)
#    246173   33.816    0.000   57.945    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\algorithms\components\biconnected.py:332(_biconnected_dfs)
#    217248    0.205    0.000   58.190    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\algorithms\components\biconnected.py:258(articulation_points)
#     42859    0.046    0.000    0.054    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\utils\decorators.py:84(_not_implemented_for)
#     42859    0.008    0.000    0.008    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:1492(is_directed)
#     34485    0.023    0.000    0.031    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:439(__iter__)
#     26111    0.034    0.000    0.070    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_connected_components_1)
#     21924    0.008    0.000    0.008    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\reportviews.py:1097(__call__)
#     21924    0.009    0.000    0.009    0.000 {method 'items' of 'dict' objects}
#      8374    0.787    0.000    0.787    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:667(remove_nodes_from)
#      8374    0.013    0.000    0.025    0.000 <class 'networkx.utils.decorators.argmap'> compilation 8:1(argmap_articulation_points_5)
#      8374    0.009    0.000    0.014    0.000 <class 'networkx.utils.decorators.argmap'> compilation 12:1(argmap__biconnected_dfs_9)
#      4982    0.001    0.000    0.002    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:330(<genexpr>)
#      4880    0.001    0.000    0.001    0.000 {built-in method unicodedata.east_asian_width}
#      4289    0.170    0.000   10.506    0.002 {built-in method builtins.max}
#      4187   24.313    0.006  120.345    0.029 C:\Users\kuzne\AppData\Local\Temp\ipykernel_54200\450216484.py:1(cascade_remove_links)
#      4187    0.092    0.000   58.316    0.014 C:\Users\kuzne\AppData\Local\Temp\ipykernel_54200\95924831.py:1(articulation_points_multiplex)
#      4187    0.108    0.000  190.091    0.045 C:\Users\kuzne\AppData\Local\Temp\ipykernel_54200\2010213982.py:1(remove_ap)
#      4187    0.016    0.000   10.534    0.003 C:\Users\kuzne\AppData\Local\Temp\ipykernel_54200\3471748023.py:1(max_comp)
#      4187    0.009    0.000    0.009    0.000 {method 'union' of 'set' objects}
#      4104    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#      4000    0.020    0.000    0.037    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\functools.py:961(__get__)
#      2210    0.002    0.000    0.002    0.000 {built-in method builtins.hasattr}
#      2142    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#      2104    0.001    0.000    0.001    0.000 {built-in method builtins.abs}
#      2000    0.001    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:37(__set__)
#      2000    0.003    0.000    0.003    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:59(__set__)
#      2000    0.009    0.000    0.013    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:337(__init__)
#      2000    0.004    0.000    0.006    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:379(adj)
#      2000    2.113    0.001    2.307    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:567(add_nodes_from)
#      2000    0.003    0.000    0.009    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\graph.py:1293(edges)
#      2000    0.004    0.000    0.006    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\networkx\classes\reportviews.py:1065(__init__)
#      2000   10.222    0.005   59.496    0.030 c:\Users\kuzne\Documents\ACTIVE_PROJECTS\research\experiments\network_models\scale_free_network.py:7(scale_free_network)
#      2000    0.021    0.000    0.021    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#      2000    0.018    0.000    0.018    0.000 {built-in method numpy.arange}
#      1000    0.015    0.000   59.512    0.060 c:\Users\kuzne\Documents\ACTIVE_PROJECTS\research\experiments\network_models\multiplex_network.py:1(create_multiplex_network)
#      1000    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#      1000    0.001    0.000    0.001    0.000 {method 'lower' of 'str' objects}
#       827    0.052    0.000    0.052    0.000 {method 'acquire' of '_thread.lock' objects}
#       813    0.002    0.000    0.002    0.000 {method 'format' of 'str' objects}
#       601    0.001    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:233(__call__)
#       508    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#       416    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:546(is_set)
#       415    0.000    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:1095(_wait_for_tstate_lock)
#       415    0.001    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:1162(is_alive)
#       414    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       402    0.000    0.000    0.000    0.000 {built-in method time.time}
#       312    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       311    0.015    0.000    0.015    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\zmq\sugar\socket.py:545(send)
#       311    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\ipykernel\iostream.py:90(_event_pipe)
#       311    0.001    0.000    0.018    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\ipykernel\iostream.py:202(schedule)
#       208    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:1138(ident)
#       207    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#       206    0.001    0.000    0.076    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:143(inner)
#       204    0.001    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:222(_is_ascii)
#       203    0.000    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:288(format_interval)
#       105    0.000    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:104(acquire)
#       105    0.000    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:108(release)
#       105    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       105    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       105    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       105    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       104    0.001    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:236(__init__)
#       104    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:264(__enter__)
#       104    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:267(__exit__)
#       104    0.000    0.000    0.002    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:538(__init__)
#       104    0.001    0.000    0.054    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:582(wait)
#       104    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:1423(current_thread)
#       104    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\ipykernel\iostream.py:429(_is_master_process)
#       104    0.000    0.000    0.013    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\ipykernel\iostream.py:448(_schedule_flush)
#       104    0.001    0.000    0.062    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\ipykernel\iostream.py:463(flush)
#       104    0.001    0.000    0.015    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\ipykernel\iostream.py:518(write)
#       104    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#       104    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       104    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       104    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       104    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#       103    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:273(_release_save)
#       103    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:276(_acquire_restore)
#       103    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:279(_is_owned)
#       103    0.001    0.000    0.053    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\threading.py:288(wait)
#       103    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       102    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:155(__init__)
#       102    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:165(colour)
#       102    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:169(colour)
#       102    0.000    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:188(__format__)
#       102    0.000    0.000    0.076    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:342(fp_write)
#       102    0.000    0.000    0.080    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:348(print_status)
#       102    0.003    0.000    0.008    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:355(format_meter)
#       102    0.001    0.000    0.009    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1164(__str__)
#       102    0.001    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1460(format_dict)
#       102    0.000    0.000    0.090    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1478(display)
#       102    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:57(__init__)
#       102    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:61(__format__)
#       102    0.000    0.000    0.003    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:329(_text_width)
#       102    0.000    0.000    0.004    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:333(disp_len)
#       102    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       102    0.001    0.000    0.003    0.000 {built-in method builtins.sum}
#       101    0.001    0.000    0.094    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1174(__iter__)
#       101    0.000    0.000    0.091    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1339(refresh)
#       101    0.000    0.000    0.000    0.000 {built-in method now}
#       100    0.001    0.000    0.092    0.001 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1212(update)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:112(__enter__)
#         4    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:115(__exit__)
#         4    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:171(__eq__)
#         3    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\_weakrefset.py:63(__iter__)
#         3    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:228(__init__)
#         3    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:101(wrapper_setattr)
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\_weakrefset.py:17(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\_weakrefset.py:21(__enter__)
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\_weakrefset.py:27(__exit__)
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\_weakrefset.py:53(_commit_removals)
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1167(_comparable)
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1171(__hash__)
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1300(fp_write)
#         2    0.000    0.000    0.001    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1279(close)
#         2    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:136(disable_on_exception)
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\_weakrefset.py:86(add)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\_weakrefset.py:111(remove)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\ctypes\__init__.py:48(create_string_buffer)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\_monitor.py:94(report)
#         1    0.000    0.000    0.002    0.002 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:329(status_printer)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:560(__new__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:579(<setcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:576(_get_free_pos)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:583(_decr_instances)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:657(get_lock)
#         1    0.000    0.000    0.003    0.003 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:846(__init__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1161(__del__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\std.py:1315(<lambda>)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:74(__eq__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:88(__getattr__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:105(__init__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:162(__init__)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:201(_is_utf)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:215(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:231(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 c:\Users\kuzne\anaconda3\envs\graphs\lib\site-packages\tqdm\utils.py:246(_screen_shape_windows)
#         1    0.036    0.036  249.739  249.739 C:\Users\kuzne\AppData\Local\Temp\ipykernel_54200\2128681892.py:1(run)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFD0B4B6CD0}

# %%
with open('results/results_2023-02-23 13-38-54.263863.json', 'r') as json_file:
    results = json.load(json_file)
    # N = results['N']
    # nruns = results['nruns']
    # crange = np.linspace(*results['crange'])
    # results = results['results']
    N = 10_000
    nruns = 100
    crange = np.linspace(0, 7, 100)

# %%
T = []
for result in results:
    T.append(np.mean([
        max(item['t'] for item in run['cascade'])
        for run in result['runs']
    ]))

max_t = max(item['t']
            for result in results
            for run in result['runs']
            for item in run['cascade'])

# %%
max_t
# Out:
# 43

# %%
# for result in results:
#     for i, run in enumerate(result['runs']):
#         tvals = [item['t'] for item in run['cascade']]
#         for t in range(max(tvals), max_t + 1):
#             if result['c'] > 5:
#                 run['cascade'].append({
#                     't': t,
#                     'n_ap': 0,
#                     'gcc_size': N,
#                 })

# %%
n_ap = {t: [] for t in range(max_t + 1)}
gcc_size = {t: [] for t in range(max_t + 1)}

for result in results:

    n_ap_loc = {t: 0 for t in range(max_t + 1)}
    gcc_size_loc = {t: 0 for t in range(max_t + 1)}
    num_gcc_t = {t: 0 for t in range(max_t + 1)}

    for run in result['runs']:
        for item in run['cascade']:

            n_ap_loc[item['t']] += item['n_ap']
            gcc_size_loc[item['t']] += item['gcc_size']
            num_gcc_t[item['t']] += 1

    for t in range(max_t + 1):

        n_ap[t].append(n_ap_loc[t] / nruns / N)
        gcc_size[t].append(gcc_size_loc[t] / num_gcc_t[t] / N
                           if num_gcc_t[t]
                           else gcc_size[t - 1][-1])

# %%
gcc_inf = []
for i, t in enumerate(np.rint(T)):
    gcc_inf.append(gcc_size[t][i])

# %%
lw, ms = 1, 3
max_t_for_plots = min(10, max_t)

# %%
plt.plot(crange, n_ap[0], 'o-', lw=lw, ms=ms, color='tab:blue', label='$t = 0$')
for t in range(1, max_t_for_plots + 1):
    plt.plot(crange, n_ap[t], '-', lw=lw, ms=ms, color='tab:green')
plt.plot(crange, n_ap[max_t_for_plots], 'o-', lw=lw, ms=ms, color='tab:red', label=f'$t = {max_t_for_plots}$')
# plt.xlim(2, 7)
plt.ylim(bottom=0)
plt.xlabel('$c$', fontdict={'size': 18})
plt.ylabel('$n_{AP}$', fontdict={'size': 18})
plt.legend(fontsize=14)
if save_results:
    plt.savefig(f'AP_{dt()}.png')

# %%
plt.plot(crange, gcc_size[0], 'o-', lw=lw, ms=ms, color='tab:blue', label='$t = 0$')
# for t in range(1, max_t_for_plots + 1):
for t in range(1, max_t_for_plots):
    plt.plot(crange, gcc_size[t], '-', lw=lw, ms=ms, color='tab:green')
# plt.plot(crange, gcc_inf, 'o-', lw=lw, ms=ms, color='tab:red', label='$t = \infty$')
plt.plot(crange, gcc_size[max_t_for_plots], '-', lw=lw, ms=ms, color='tab:red', label=f'$t = {max_t_for_plots}$')
# plt.xlim(2, 7)
# plt.ylim(0, 1)
plt.xlabel('$c$', fontdict={'size': 18})
plt.ylabel('GCC Size', fontdict={'size': 18})
plt.legend(fontsize=14)
if save_results:
    plt.savefig(f'GCC_size_{dt()}.png')

# %%
plt.semilogy(crange, np.rint(T), 'o-', ms=ms, lw=lw, color='tab:green', label='$t = \infty$')
# plt.xlim(2, 7)
plt.ylim(bottom=1)
plt.xlabel('$c$', fontdict={'size': 18})
plt.ylabel('t', fontdict={'size': 18})
plt.legend(fontsize=14)
if save_results:
    plt.savefig(f't_{dt()}.png')
